# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data=pd.read_csv('C:\\Users\\PC\\Downloads\\Telegram Desktop\\newhousing2.csv')

# %%
data
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.23     37.88                  41          880           129.0
# 1       -122.22     37.86                  21         7099          1106.0
# 2       -122.24     37.85                  52         1467           190.0
# 3       -122.25     37.85                  52         1274           235.0
# 4       -122.25     37.85                  52         1627           280.0
# ...         ...       ...                 ...          ...             ...
# 1494    -122.02     37.94                  19         3192           612.0
# 1495    -122.01     37.94                  26         1619           224.0
# 1496    -122.01     37.94                  18         2077           298.0
# 1497    -122.00     37.95                   9         2214           256.0
# 1498    -122.01     37.93                  25         2652           335.0
#
#       population  households  median_income  median_house_value  \
# ...

# %%
data.drop(['housing_median_age','total_rooms','total_bedrooms','population','households','median_house_value','ocean_proximity'],axis='columns',inplace=True)
data.head()
# Out:
#    longitude  latitude  median_income
# 0    -122.23     37.88         8.3252
# 1    -122.22     37.86         8.3014
# 2    -122.24     37.85         7.2574
# 3    -122.25     37.85         5.6431
# 4    -122.25     37.85         3.8462

# %%
kmeans = KMeans(n_clusters=3)
data["Cluster"] = kmeans.fit_predict(data)
data["Cluster"] = data["Cluster"].astype("category")

data.head()
# Out:
#    longitude  latitude  median_income Cluster
# 0    -122.23     37.88         8.3252       0
# 1    -122.22     37.86         8.3014       0
# 2    -122.24     37.85         7.2574       0
# 3    -122.25     37.85         5.6431       0
# 4    -122.25     37.85         3.8462       2

# %%
sns.relplot(
    x="longitude", y="latitude", hue="Cluster", data=data, height=10,)
